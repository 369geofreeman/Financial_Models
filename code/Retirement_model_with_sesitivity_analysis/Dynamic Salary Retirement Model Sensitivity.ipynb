# %% [markdown]
# # Retirement Model
#
# This is a retirement model which models salary with both a constant growth rate for cost of living raises as well as regular salary increases for promotions. The model is broken up into the following sections:
#
# - [**Setup**](#Setup): Runs any imports and other setup
# - [**Inputs**](#Inputs): Defines the inputs for the model
# - [**Salaries**](#Salaries): Determining the salary in each year, considering cost of living raises and promotions
# - [**Wealths**](#Wealths): Determining the wealth in each year, considering a constant savings rate and investment rate
# - [**Retirement**](#Retirement): Determines years to retirement from the wealths over time, the main output from the model.
# - [**Results Summary**](#Results-Summary): Summarize the results with some visualizations
# - [**Sensitivity Analysis**](#Sensitivity-Analysis): Determine how sensitive the years to retirement is to the model inputs

# %% [markdown]
# ## Setup
#
# Setup for the later calculations are here. The necessary packages are imported.

# %%
from dataclasses import dataclass
import pandas as pd
from sensitivity import SensitivityAnalyzer
# %matplotlib inline

# %% [markdown]
# ## Inputs
#
# All of the inputs for the model are defined here. A class is constructed to manage the data, and an instance of the class containing the default inputs is created.

# %%
@dataclass
class ModelInputs:
    starting_salary: int = 60000
    promos_every_n_years: int = 5
    cost_of_living_raise: float = 0.02
    promo_raise: float = 0.15
    savings_rate: float = 0.25
    interest_rate: float = 0.05
    desired_cash: int = 1500000
        
model_data = ModelInputs()
model_data
# Out:
# ModelInputs(starting_salary=60000, promos_every_n_years=5, cost_of_living_raise=0.02, promo_raise=0.15, savings_rate=0.25, interest_rate=0.05, desired_cash=1500000)

# %% [markdown]
# ## Salaries
#
# Here the salary for each year is calculated. We assume that the salary grows at a constant rate each year for cost of living raises, and then also every number of years, the salary increases by a further percentage due to a promotion or switching jobs. Based on this assumption, the salary would evolve over time with the following equation:
#
# $$s_t = s_0 (1 + r_{cl})^n (1 + r_p)^p$$
#
# Where:
# - $s_t$: Salary at year $t$
# - $s_0$: Starting salary (year 0)
# - $r_{cl}$: Annual cost of living raise
# - $r_p$: Promotion raise
# - $p$: Number of promotions
#
# And in Python format:

# %%
def salary_at_year(data: ModelInputs, year):
    """
    Gets the salary at a given year from the start of the model based on cost of living raises and regular promotions.
    """
    # Every n years we have a promotion, so dividing the years and taking out the decimals gets the number of promotions
    num_promos = int(year / data.promos_every_n_years)
    
    # This is the formula above implemented in Python
    salary_t = data.starting_salary * (1 + data.cost_of_living_raise) ** year * (1 + data.promo_raise) ** num_promos
    return salary_t

# %% [markdown]
# That function will get the salary at a given year, so to get all the salaries we just run it on each year. But we will not know how many years to run as we should run it until the individual is able to retire. So we are just showing the first few salaries for now and will later use this function in the [Wealths](#Wealths) section of the model.

# %%
for i in range(6):
    year = i + 1
    salary = salary_at_year(model_data, year)
    print(f'The salary at year {year} is ${salary:,.0f}.')
# Out:
# The salary at year 1 is $61,200.
# The salary at year 2 is $62,424.
# The salary at year 3 is $63,672.
# The salary at year 4 is $64,946.
# The salary at year 5 is $76,182.
# The salary at year 6 is $77,705.

# %% [markdown]
# As expected, with the default inputs, the salary is increasing at 2% per year. Then at year 5, there is a promotion so there is a larger increase in salary.

# %% [markdown]
# ## Wealths
#
# The wealths portion of the model is concerned with applying the savings rate to the earned salary to calculate the cash saved, accumulating the cash saved over time, and applying the investment rate to the accumulated wealth.
#
# To calculate cash saved, it is simply:
#
# $$c_t = s_t * r_s$$
#
# Where:
# - $c_t$: Cash saved during year $t$
# - $r_s$: Savings rate

# %%
def cash_saved_during_year(data: ModelInputs, year):
    """
    Calculated the cash saved within a given year, by first calculating the salary at that year then applying the 
    savings rate.
    """
    salary = salary_at_year(data, year)
    cash_saved = salary * data.savings_rate
    return cash_saved

# %% [markdown]
# To get the wealth at each year, it is just applying the investment return to last year's wealth, then adding this year's cash saved:
#
# $$w_t = w_{t-1} (1 + r_i) + c_t$$
# Where:
# - $w_t$: Wealth at year $t$
# - $r_i$: Investment rate

# %%
def wealth_at_year(data: ModelInputs, year, prior_wealth):
    """
    Calculate the accumulated wealth for a given year, based on previous wealth, the investment rate,
    and cash saved during the year.
    """
    cash_saved = cash_saved_during_year(data, year)
    wealth = prior_wealth * (1 + data.interest_rate) + cash_saved
    return wealth

# %% [markdown]
# Again, just like in the [Salaries](#Salaries) section, we can now get the output for each year, but we don't know ultimately how many years we will have to run it. That will be determined in the [Retirement](#Retirement) section. So for now, just show the first few years of wealth accumulation:

# %%
prior_wealth = 0  # starting with no cash saved
for i in range(6):
    year = i + 1
    wealth = wealth_at_year(model_data, year, prior_wealth)
    print(f'The wealth at year {year} is ${wealth:,.0f}.')
    
    # Set next year's prior wealth to this year's wealth
    prior_wealth = wealth
# Out:
# The wealth at year 1 is $15,300.
# The wealth at year 2 is $31,671.
# The wealth at year 3 is $49,173.
# The wealth at year 4 is $67,868.
# The wealth at year 5 is $90,307.
# The wealth at year 6 is $114,248.

# %% [markdown]
# With default inputs, the wealth is going up by approximately 25% of the salary each year, plus a bit more for investment. Then in year 6 we see a substantially larger increase because the salary is substantially larger due to the promotion. So everything is looking correct.

# %% [markdown]
# ## Retirement
#
# This section of the model puts everything together to produce the final output of years to retirement. It uses the logic to get the wealths at each year, which in turn uses the logic to the get salary at each year. The wealth at each year is tracked over time until it hits the desired cash. Once the wealth hits the desired cash, the individual is able to retire so that year is returned as the years to retirement.

# %%
def years_to_retirement(data: ModelInputs, print_output=False):
    
    # starting with no cash saved
    prior_wealth = 0  
    wealth = 0
    
    year = 0  # will become 1 on first loop
    
    if print_output:
        print('Wealths over time:') # \n makes a blank line in the output.
    while wealth < data.desired_cash:
        year = year + 1
        wealth = wealth_at_year(data, year, prior_wealth)
        if print_output:
            print(f'The wealth at year {year} is ${wealth:,.0f}.')

        # Set next year's prior wealth to this year's wealth
        prior_wealth = wealth
        
    # Now we have exited the while loop, so wealth must be >= desired_cash. Whatever last year was set
    # is the years to retirement.
    if print_output:
        print(f'\nRetirement:\nIt will take {year} years to retire.')  # \n makes a blank line in the output.
    return year

# %% [markdown]
# With the default inputs:

# %%
years = years_to_retirement(model_data, print_output=True)
# Out:
# Wealths over time:
# The wealth at year 1 is $15,300.
# The wealth at year 2 is $31,671.
# The wealth at year 3 is $49,173.
# The wealth at year 4 is $67,868.
# The wealth at year 5 is $90,307.
# The wealth at year 6 is $114,248.
# The wealth at year 7 is $139,775.
# The wealth at year 8 is $166,975.
# The wealth at year 9 is $195,939.
# The wealth at year 10 is $229,918.
# The wealth at year 11 is $266,080.
# The wealth at year 12 is $304,542.
# The wealth at year 13 is $345,431.
# The wealth at year 14 is $388,878.
# The wealth at year 15 is $439,025.
# The wealth at year 16 is $492,294.
# The wealth at year 17 is $548,853.
# The wealth at year 18 is $608,878.
# The wealth at year 19 is $672,557.
# The wealth at year 20 is $745,168.
# The wealth at year 21 is $822,190.
# The wealth at year 22 is $903,859.
# The wealth at year 23 is $990,422.
# The wealth at year 24 is $1,082,140.
# The wealth at year 25 is $1,185,745.
# The wealth at year 26 is $1,295,520.
# The wealth at year 27 is $1,411,793.
# The wealth at year 28 is $1,534,910.
#
# Retirement:
# It will take 28 years to retire.

# %% [markdown]
# # Results Summary
#
# ## Put Results in a Table
#
# Now I will visualize the salaries and wealths over time. First create a function which runs the model to put these results in a DataFrame.

# %%
def get_salaries_wealths_df(data):
    """
    Runs the retirement model, collecting salary and wealth information year by year and storing
    into a DataFrame for further analysis.
    """
    # starting with no cash saved
    prior_wealth = 0  
    wealth = 0
    
    year = 0  # will become 1 on first loop
    
    df_data_tups = []
    while wealth < data.desired_cash:
        year = year + 1
        salary = salary_at_year(data, year)
        wealth = wealth_at_year(data, year, prior_wealth)

        # Set next year's prior wealth to this year's wealth
        prior_wealth = wealth
        
        # Save the results in a tuple for later building the DataFrame
        df_data_tups.append((year, salary, wealth))
        
    # Now we have exited the while loop, so wealth must be >= desired_cash
    
    # Now create the DataFrame
    df = pd.DataFrame(df_data_tups, columns=['Year', 'Salary', 'Wealth'])
    
    return df

# %% [markdown]
# Also set up a function which formats the `DataFrame` for display.

# %%
def styled_salaries_wealths(df):
    return df.style.format({
        'Salary': '${:,.2f}',
        'Wealth': '${:,.2f}'
    })

# %% [markdown]
# Now call the function to save the results into the `DataFrame`.

# %%
df = get_salaries_wealths_df(model_data)
styled_salaries_wealths(df)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bee02_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Year</th>
#       <th class="col_heading level0 col1" >Salary</th>
#       <th class="col_heading level0 col2" >Wealth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bee02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bee02_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_bee02_row0_col1" class="data row0 col1" >$61,200.00</td>
#       <td id="T_bee02_row0_col2" class="data row0 col2" >$15,300.00</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bee02_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_bee02_row1_col1" class="data row1 col1" >$62,424.00</td>
#       <td id="T_bee02_row1_col2" class="data row1 col2" >$31,671.00</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bee02_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_bee02_row2_col1" class="data row2 col1" >$63,672.48</td>
#       <td id="T_bee02_row2_col2" class="data row2 col2" >$49,172.67</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bee02_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_bee02_row3_col1" class="data row3 col1" >$64,945.93</td>
#       <td id="T_bee02_row3_col2" class="data row3 col2" >$67,867.79</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bee02_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_bee02_row4_col1" class="data row4 col1" >$76,181.58</td>
#       <td id="T_bee02_row4_col2" class="data row4 col2" >$90,306.57</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bee02_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_bee02_row5_col1" class="data row5 col1" >$77,705.21</td>
#       <td id="T_bee02_row5_col2" class="data row5 col2" >$114,248.20</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bee02_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_bee02_row6_col1" class="data row6 col1" >$79,259.31</td>
#       <td id="T_bee02_row6_col2" class="data row6 col2" >$139,775.44</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bee02_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_bee02_row7_col1" class="data row7 col1" >$80,844.50</td>
#       <td id="T_bee02_row7_col2" class="data row7 col2" >$166,975.33</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bee02_row8_col0" class="data row8 col0" >9</td>
#       <td id="T_bee02_row8_col1" class="data row8 col1" >$82,461.39</td>
#       <td id="T_bee02_row8_col2" class="data row8 col2" >$195,939.45</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bee02_row9_col0" class="data row9 col0" >10</td>
#       <td id="T_bee02_row9_col1" class="data row9 col1" >$96,727.21</td>
#       <td id="T_bee02_row9_col2" class="data row9 col2" >$229,918.22</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bee02_row10_col0" class="data row10 col0" >11</td>
#       <td id="T_bee02_row10_col1" class="data row10 col1" >$98,661.75</td>
#       <td id="T_bee02_row10_col2" class="data row10 col2" >$266,079.57</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bee02_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_bee02_row11_col1" class="data row11 col1" >$100,634.99</td>
#       <td id="T_bee02_row11_col2" class="data row11 col2" >$304,542.29</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bee02_row12_col0" class="data row12 col0" >13</td>
#       <td id="T_bee02_row12_col1" class="data row12 col1" >$102,647.69</td>
#       <td id="T_bee02_row12_col2" class="data row12 col2" >$345,431.33</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bee02_row13_col0" class="data row13 col0" >14</td>
#       <td id="T_bee02_row13_col1" class="data row13 col1" >$104,700.64</td>
#       <td id="T_bee02_row13_col2" class="data row13 col2" >$388,878.06</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bee02_row14_col0" class="data row14 col0" >15</td>
#       <td id="T_bee02_row14_col1" class="data row14 col1" >$122,813.85</td>
#       <td id="T_bee02_row14_col2" class="data row14 col2" >$439,025.42</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bee02_row15_col0" class="data row15 col0" >16</td>
#       <td id="T_bee02_row15_col1" class="data row15 col1" >$125,270.13</td>
#       <td id="T_bee02_row15_col2" class="data row15 col2" >$492,294.23</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bee02_row16_col0" class="data row16 col0" >17</td>
#       <td id="T_bee02_row16_col1" class="data row16 col1" >$127,775.53</td>
#       <td id="T_bee02_row16_col2" class="data row16 col2" >$548,852.82</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bee02_row17_col0" class="data row17 col0" >18</td>
#       <td id="T_bee02_row17_col1" class="data row17 col1" >$130,331.04</td>
#       <td id="T_bee02_row17_col2" class="data row17 col2" >$608,878.22</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bee02_row18_col0" class="data row18 col0" >19</td>
#       <td id="T_bee02_row18_col1" class="data row18 col1" >$132,937.66</td>
#       <td id="T_bee02_row18_col2" class="data row18 col2" >$672,556.55</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_bee02_row19_col0" class="data row19 col0" >20</td>
#       <td id="T_bee02_row19_col1" class="data row19 col1" >$155,935.88</td>
#       <td id="T_bee02_row19_col2" class="data row19 col2" >$745,168.34</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_bee02_row20_col0" class="data row20 col0" >21</td>
#       <td id="T_bee02_row20_col1" class="data row20 col1" >$159,054.59</td>
#       <td id="T_bee02_row20_col2" class="data row20 col2" >$822,190.41</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_bee02_row21_col0" class="data row21 col0" >22</td>
#       <td id="T_bee02_row21_col1" class="data row21 col1" >$162,235.69</td>
#       <td id="T_bee02_row21_col2" class="data row21 col2" >$903,858.85</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_bee02_row22_col0" class="data row22 col0" >23</td>
#       <td id="T_bee02_row22_col1" class="data row22 col1" >$165,480.40</td>
#       <td id="T_bee02_row22_col2" class="data row22 col2" >$990,421.89</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_bee02_row23_col0" class="data row23 col0" >24</td>
#       <td id="T_bee02_row23_col1" class="data row23 col1" >$168,790.01</td>
#       <td id="T_bee02_row23_col2" class="data row23 col2" >$1,082,140.49</td>
#     </tr>
#     <tr>
#       <th id="T_bee02_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_bee02_row24_col0" class="data row24 col0" >25</td>
#       <td id="T_bee02_row24_col1" class="data row24 col1" >$197

# %% [markdown]
# ## Plot Results
#
# Now I will visualize the salaries and wealths over time.

# %% [markdown]
# ### Salaries over Time

# %%
df.plot.line(x='Year', y='Salary')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# ### Wealths over Time

# %%
df.plot.line(x='Year', y='Wealth')
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
df.plot.line(x='Year', y='Salary')
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # Sensitivity Analysis
#
# Now I will determine how the years to retirement change in response to the different inputs.
#
# To use `SensitivityAnalyzer`, first we need a function which accepts the individual parameters rather than the entire data. Here we will use a Python shortcut `**kwargs`. This just means it can accept any amount of optional (keyword) arguments. Then inside the function, we are taking everything passed to the function and passing it to the `ModelInputs` class.

# %%
def years_to_retirement_separate_args(**kwargs):
    data = ModelInputs(**kwargs)
    return years_to_retirement(data)

years_to_retirement_separate_args(starting_salary=100000)
# Out:
# 22

# %% [markdown]
# Now pick the values we want to look at for each input.

# %%
# It is certainly possible to specify all these hard-coded but using list comprehensions makes it easy to adjust
sensitivity_values = {
    'starting_salary': [i * 10000 for i in range(4, 8)],
    'promos_every_n_years': [i for i in range(4, 8)],
    'cost_of_living_raise': [i/100 for i in range(1, 4)],
    'promo_raise': [i/100 for i in range(10, 25, 5)],
    'savings_rate': [i/100 for i in range(10, 50, 10)],
    'interest_rate': [i/100 for i in range(3, 8)],
    'desired_cash': [i * 100000 for i in range(10, 26, 5)]
}

# Note: these are optional but improve the formatting of the output
labels = {
    'starting_salary': 'Starting Salary',
    'promos_every_n_years': 'Promos Every N Years',
    'cost_of_living_raise': 'Cost of Living Raise',
    'promo_raise': 'Promotion Raise',
    'savings_rate': 'Savings Rate',
    'interest_rate': 'Interest Rate',
    'desired_cash': 'Desired Cash'
}

# %%
sa = SensitivityAnalyzer(
    sensitivity_values,
    years_to_retirement_separate_args,
    result_name='Years to Retirement',
    reverse_colors=True,
    grid_size=3,
    labels=labels
)
# Out:
# 100%|██████████| 11520/11520 [00:12<00:00, 953.13it/s]

# %% [markdown]
# Now we've just run the model 11,520 times with all the combinations of the inputs.

# %%
sa.df
# Out:
#        Starting Salary  Promos Every N Years  Cost of Living Raise  \
# 0                40000                     4                  0.01
# 1                40000                     4                  0.01
# 2                40000                     4                  0.01
# 3                40000                     4                  0.01
# 4                40000                     4                  0.01
# ...                ...                   ...                   ...
# 11515            70000                     7                  0.03
# 11516            70000                     7                  0.03
# 11517            70000                     7                  0.03
# 11518            70000                     7                  0.03
# 11519            70000                     7                  0.03
#
#        Promotion Raise  Savings Rate  Interest Rate  Desired Cash  \
# 0                  0.1           0.1           0.03       1000000
# 1                  0.1           0.1           0.03       1500000
# 2                  0.1           0.1           0.03       2000000
# 3                  0.1           0.1           0.03       2500000
# 4                  0.1           0.1           0.04       1000000
# ...                ...           ...            ...           ...
# 11515              0.2           0.4           0.06       2500000
# 11516              0.2           0.4           0.07       1000000
# 11517              0.2           0.4           0.07       1500000
# 11518              0.2           0.4           0.07       2000000
# 11519              0.2           0.4           0.07       2500000
#
#        Years to Retirement
# 0                       52
# 1                       60
# 2                       66
# 3                       71
# 4                       47
# ...                    ...
# 11515                   25
# 11516                   16
# 11517                   19
# 11518                   22
# 11519                   24
#
# [11520 rows x 8 columns]

# %% [markdown]
# Display as hex-bin plots.

# %%
plot = sa.plot()

# %% [markdown]
# Display as styled DataFrames with conditional formatting.

# %%
styled_dict = sa.styled_dfs(num_fmt='{:.1f}')
# Out:
# <h2>Years to Retirement by Starting Salary vs. Promos Every N Years</h2>
# <style type="text/css">
# #T_c13fd_row0_col0 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_c13fd_row0_col1 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# #T_c13fd_row0_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_c13fd_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c13fd_row1_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_c13fd_row1_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_c13fd_row1_col2 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_c13fd_row1_col3 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_c13fd_row2_col0 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_c13fd_row2_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_c13fd_row2_col2 {
#   background-color: #d7ee8a;
#   color: #000000;
# }
# #T_c13fd_row2_col3 {
#   background-color: #f2faae;
#   color: #000000;
# }
# #T_c13fd_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c13fd_row3_col1 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_c13fd_row3_col2 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_c13fd_row3_col3 {
#   background-color: #96d268;
#   color: #000000;
# }
# </style>
# <table id="T_c13fd_">
#   <caption>Years to Retirement - Starting Salary vs. Promos Every N Years</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >4</th>
#       <th class="col_heading level0 col1" >5</th>
#       <th class="col_heading level0 col2" >6</th>
#       <th class="col_heading level0 col3" >7</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Starting Salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c13fd_level0_row0" class="row_heading level0 row0" >40000</th>
#       <td id="T_c13fd_row0_col0" class="data row0 col0" >35.1</td>
#       <td id="T_c13fd_row0_col1" class="data row0 col1" >36.8</td>
#       <td id="T_c13fd_row0_col2" class="data row0 col2" >38.0</td>
#       <td id="T_c13fd_row0_col3" class="data row0 col3" >38.9</td>
#     </tr>
#     <tr>
#       <th id="T_c13fd_level0_row1" class="row_heading level0 row1" >50000</th>
#       <td id="T_c13fd_row1_col0" class="data row1 col0" >32.4</td>
#       <td id="T_c13fd_row1_col1" class="data row1 col1" >33.9</td>
#       <td id="T_c13fd_row1_col2" class="data row1 col2" >35.0</td>
#       <td id="T_c13fd_row1_col3" class="data row1 col3" >35.8</td>
#     </tr>
#     <tr>
#       <th id="T_c13fd_level0_row2" class="row_heading level0 row2" >60000</th>
#       <td id="T_c13fd_row2_col0" class="data row2 col0" >30.2</td>
#       <td id="T_c13fd_row2_col1" class="data row2 col1" >31.6</td>
#       <td id="T_c13fd_row2_col2" class="data row2 col2" >32.6</td>
#       <td id="T_c13fd_row2_col3" class="data row2 col3" >33.3</td>
#     </tr>
#     <tr>
#       <th id="T_c13fd_level0_row3" class="row_heading level0 row3" >70000</th>
#       <td id="T_c13fd_row3_col0" class="data row3 col0" >28.4</td>
#       <td id="T_c13fd_row3_col1" class="data row3 col1" >29.7</td>
#       <td id="T_c13fd_row3_col2" class="data row3 col2" >30.6</td>
#       <td id="T_c13fd_row3_col3" class="data row3 col3" >31.3</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Starting Salary vs. Cost of Living Raise</h2>
# <style type="text/css">
# #T_9d4d4_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9d4d4_row0_col1 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_9d4d4_row0_col2 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_9d4d4_row1_col0 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_9d4d4_row1_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_9d4d4_row1_col2 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_9d4d4_row2_col0 {
#   background-color: #fffdbc;
#   color: #000000;
# }
# #T_9d4d4_row2_col1 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_9d4d4_row2_col2 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_9d4d4_row3_col0 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_9d4d4_row3_col1 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_9d4d4_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9d4d4_">
#   <caption>Years to Retirement - Starting Salary vs. Cost of Living Raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.01</th>
#       <th class="col_heading level0 col1" >0.02</th>
#       <th class="col_heading level0 col2" >0.03</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Starting Salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d4d4_level0_row0" class="row_heading level0 row0" >40000</th>
#       <td id="T_9d4d4_row0_col0" class="data row0 col0" >39.8</td>
#       <td id="T_9d4d4_row0_col1" class="data row0 col1" >37.1</td>
#       <td id="T_9d4d4_row0_col2" class="data row0 col2" >34.7</td>
#     </tr>
#     <tr>
#       <th id="T_9d4d4_level0_row1" class="row_heading level0 row1" >50000</th>
#       <td id="T_9d4d4_row1_col0" class="data row1 col0" >36.6</td>
#       <td id="T_9d4d4_row1_col1" class="data row1 col1" >34.2</td>
#       <td id="T_9d4d4_row1_col2" class="data row1 col2" >32.0</td>
#     </tr>
#     <tr>
#       <th id="T_9d4d4_level0_row2" class="row_heading level0 row2" >60000</th>
#       <td id="T_9d4d4_row2_col0" class="data row2 col0" >34.0</td>
#       <td id="T_9d4d4_row2_col1" class="data row2 col1" >31.9</td>
#       <td id="T_9d4d4_row2_col2" class="data row2 col2" >29.9</td>
#     </tr>
#     <tr>
#       <th id="T_9d4d4_level0_row3" class="row_heading level0 row3" >70000</th>
#       <td id="T_9d4d4_row3_col0" class="data row3 col0" >32.0</td>
#       <td id="T_9d4d4_row3_col1" class="data row3 col1" >29.9</td>
#       <td id="T_9d4d4_row3_col2" class="data row3 col2" >28.2</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Starting Salary vs. Promotion Raise</h2>
# <style type="text/css">
# #T_5a950_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_5a950_row0_col1 {
#   background-color: #f26841;
#   color: #f1f1f1;
# }
# #T_5a950_row0_col2 {
#   background-color: #fecc7b;
#   color: #000000;
# }
# #T_5a950_row1_col0 {
#   background-color: #fdaf62;
#   color: #000000;
# }
# #T_5a950_row1_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_5a950_row1_col2 {
#   background-color: #cdea83;
#   color: #000000;
# }
# #T_5a950_row2_col0 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_5a950_row2_col1 {
#   background-color: #a9da6c;
#   color: #000000;
# }
# #T_5a950_row2_col2 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_5a950_row3_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_5a950_row3_col1 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_5a950_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5a950_">
#   <caption>Years to Retirement - Starting Salary vs. Promotion Raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.1</th>
#       <th class="col_heading level0 col1" >0.15</th>
#       <th class="col_heading level0 col2" >0.2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Starting Salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a950_level0_row0" class="row_heading level0 row0" >40000</th>
#       <td id="T_5a950_row0_col0" class="data row0 col0" >39.1</td>
#       <td id="T_5a950_row0_col1" class="data row0 col1" >37.1</td>
#       <td id="T_5a950_row0_col2" class="data row0 col2" >35.4</td>
#     </tr>
#     <tr>
#       <th id="T_5a950_level0_row1" class="row_heading level0 row1" >50000</th>
#       <td id="T_5a950_row1_col0" class="data row1 col0" >36.0</td>
#       <td id="T_5a950_row1_col1" class="data row1 col1" >34.2</td>
#       <td id="T_5a950_row1_col2" class="data row1 col2" >32.6</td>
#     </tr>
#     <tr>
#       <th id="T_5a950_level0_row2" class="row_heading level0 row2" >60000</th>
#       <td id="T_5a950_row2_col0" class="data row2 col0" >33.5</td>
#       <td id="T_5a950_row2_col1" class="data row2 col1" >31.9</td>
#       <td id="T_5a950_row2_col2" class="data row2 col2" >30.5</td>
#     </tr>
#     <tr>
#       <th id="T_5a950_level0_row3" class="row_heading level0 row3" >70000</th>
#       <td id="T_5a950_row3_col0" class="data row3 col0" >31.4</td>
#       <td id="T_5a950_row3_col1" class="data row3 col1" >30.0</td>
#       <td id="T_5a950_row3_col2" class="data row3 col2" >28.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Starting Salary vs. Savings Rate</h2>
# <style type="text/css">
# #T_1157f_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_1157f_row0_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_1157f_row0_col2, #T_1157f_row2_col1 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_1157f_row0_col3 {
#   background-color: #89cc67;
#   color: #000000;
# }
# #T_1157f_row1_col0 {
#   background-color: #de402e;
#   color: #f1f1f1;
# }
# #T_1157f_row1_col1 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_1157f_row1_col2 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_1157f_row1_col3 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_1157f_row2_col0 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_1157f_row2_col2 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_1157f_row2_col3 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_1157f_row3_col0 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_1157f_row3_col1 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_1157f_row3_col2 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_1157f_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1157f_">
#   <caption>Years to Retirement - Starting Salary vs. Savings Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.1</th>
#       <th class="col_heading level0 col1" >0.2</th>
#       <th class="col_heading level0 col2" >0.3</th>
#       <th class="col_heading level0 col3" >0.4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Starting Salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1157f_level0_row0" class="row_heading level0 row0" >40000</th>
#       <td id="T_1157f_row0_col0" class="data row0 col0" >48.1</td>
#       <td id="T_1157f_row0_col1" class="data row0 col1" >38.3</td>
#       <td id="T_1157f_row0_col2" class="data row0 col2" >33.0</td>
#       <td id="T_1157f_row0_col3" class="data row0 col3" >29.3</td>
#     </tr>
#     <tr>
#       <th id="T_1157f_level0_row1" class="row_heading level0 row1" >50000</th>
#       <td id="T_1157f_row1_col0" class="data row1 col0" >44.9</td>
#       <td id="T_1157f_row1_col1" class="data row1 col1" >35.3</td>
#       <td id="T_1157f_row1_col2" class="data row1 col2" >30.1</td>
#       <td id="T_1157f_row1_col3" class="data row1 col3" >26.7</td>
#     </tr>
#     <tr>
#       <th id="T_1157f_level0_row2" class="row_heading level0 row2" >60000</th>
#       <td id="T_1157f_row2_col0" class="data row2 col0" >42.3</td>
#       <td id="T_1157f_row2_col1" class="data row2 col1" >33.0</td>
#       <td id="T_1157f_row2_col2" class="data row2 col2" >27.9</td>
#       <td id="T_1157f_row2_col3" class="data row2 col3" >24.6</td>
#     </tr>
#     <tr>
#       <th id="T_1157f_level0_row3" class="row_heading level0 row3" >70000</th>
#       <td id="T_1157f_row3_col0" class="data row3 col0" >40.2</td>
#       <td id="T_1157f_row3_col1" class="data row3 col1" >31.0</td>
#       <td id="T_1157f_row3_col2" class="data row3 col2" >26.1</td>
#       <td id="T_1157f_row3_col3" class="data row3 col3" >22.9</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Starting Salary vs. Interest Rate</h2>
# <style type="text/css">
# #T_a01c1_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_a01c1_row0_col1 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_a01c1_row0_col2 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_a01c1_row0_col3 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_a01c1_row0_col4 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_a01c1_row1_col0 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_a01c1_row1_col1 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_a01c1_row1_col2 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_a01c1_row1_col3 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_a01c1_row1_col4 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_a01c1_row2_col0 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_a01c1_row2_col1 {
#   background-color: #ecf7a6;
#   color: #000000;
# }
# #T_a01c1_row2_col2 {
#   background-color: #b1de71;
#   color: #000000;
# }
# #T_a01c1_row2_col3 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_a01c1_row2_col4 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_a01c1_row3_col0 {
#   background-color: #eef8a8;
#   color: #000000;
# }
# #T_a01c1_row3_col1 {
#   background-color: #afdd70;
#   color: #000000;
# }
# #T_a01c1_row3_col2 {
#   background-color: #63bc62;
#   color: #f1f1f1;
# }
# #T_a01c1_row3_col3 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_a01c1_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a01c1_">
#   <caption>Years to Retirement - Starting Salary vs. Interest Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.03</th>
#       <th class="col_heading level0 col1" >0.04</th>
#       <th class="col_heading level0 col2" >0.05</th>
#       <th class="col_heading level0 col3" >0.06</th>
#       <th class="col_heading level0 col4" >0.07</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Starting Salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a01c1_level0_row0" class="row_heading level0 row0" >40000</th>
#       <td id="T_a01c1_row0_col0" class="data row0 col0" >42.3</td>
#       <td id="T_a01c1_row0_col1" class="data row0 col1" >39.4</td>
#       <td id="T_a01c1_row0_col2" class="data row0 col2" >36.9</td>
#       <td id="T_a01c1_row0_col3" class="data row0 col3" >34.7</td>
#       <td id="T_a01c1_row0_col4" class="data row0 col4" >32.7</td>
#     </tr>
#     <tr>
#       <th id="T_a01c1_level0_row1" class="row_heading level0 row1" >50000</th>
#       <td id="T_a01c1_row1_col0" class="data row1 col0" >38.8</td>
#       <td id="T_a01c1_row1_col1" class="data row1 col1" >36.2</td>
#       <td id="T_a01c1_row1_col2" class="data row1 col2" >34.0</td>
#       <td id="T_a01c1_row1_col3" class="data row1 col3" >32.0</td>
#       <td id="T_a01c1_row1_col4" class="data row1 col4" >30.3</td>
#     </tr>
#     <tr>
#       <th id="T_a01c1_level0_row2" class="row_heading level0 row2" >60000</th>
#       <td id="T_a01c1_row2_col0" class="data row2 col0" >36.0</td>
#       <td id="T_a01c1_row2_col1" class="data row2 col1" >33.7</td>
#       <td id="T_a01c1_row2_col2" class="data row2 col2" >31.7</td>
#       <td id="T_a01c1_row2_col3" class="data row2 col3" >29.9</td>
#       <td id="T_a01c1_row2_col4" class="data row2 col4" >28.3</td>
#     </tr>
#     <tr>
#       <th id="T_a01c1_level0_row3" class="row_heading level0 row3" >70000</th>
#       <td id="T_a01c1_row3_col0" class="data row3 col0" >33.8</td>
#       <td id="T_a01c1_row3_col1" class="data row3 col1" >31.7</td>
#       <td id="T_a01c1_row3_col2" class="data row3 col2" >29.8</td>
#       <td id="T_a01c1_row3_col3" class="data row3 col3" >28.2</td>
#       <td id="T_a01c1_row3_col4" class="data row3 col4" >26.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Starting Salary vs. Desired Cash</h2>
# <style type="text/css">
# #T_bd996_row0_col0, #T_bd996_row2_col1 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_bd996_row0_col1 {
#   background-color: #fed27f;
#   color: #000000;
# }
# #T_bd996_row0_col2, #T_bd996_row1_col3 {
#   background-color: #ea5739;
#   color: #f1f1f1;
# }
# #T_bd996_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_bd996_row1_col0 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_bd996_row1_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_bd996_row1_col2 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_bd996_row2_col0 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_bd996_row2_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_bd996_row2_col3 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_bd996_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bd996_row3_col1 {
#   background-color: #87cb67;
#   color: #000000;
# }
# #T_bd996_row3_col2 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_bd996_row3_col3 {
#   background-color: #fee28f;
#   color: #000000;
# }
# </style>
# <table id="T_bd996_">
#   <caption>Years to Retirement - Starting Salary vs. Desired Cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1000000</th>
#       <th class="col_heading level0 col1" >1500000</th>
#       <th class="col_heading level0 col2" >2000000</th>
#       <th class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Starting Salary</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd996_level0_row0" class="row_heading level0 row0" >40000</th>
#       <td id="T_bd996_row0_col0" class="data row0 col0" >30.6</td>
#       <td id="T_bd996_row0_col1" class="data row0 col1" >35.8</td>
#       <td id="T_bd996_row0_col2" class="data row0 col2" >39.6</td>
#       <td id="T_bd996_row0_col3" class="data row0 col3" >42.8</td>
#     </tr>
#     <tr>
#       <th id="T_bd996_level0_row1" class="row_heading level0 row1" >50000</th>
#       <td id="T_bd996_row1_col0" class="data row1 col0" >27.9</td>
#       <td id="T_bd996_row1_col1" class="data row1 col1" >32.9</td>
#       <td id="T_bd996_row1_col2" class="data row1 col2" >36.6</td>
#       <td id="T_bd996_row1_col3" class="data row1 col3" >39.6</td>
#     </tr>
#     <tr>
#       <th id="T_bd996_level0_row2" class="row_heading level0 row2" >60000</th>
#       <td id="T_bd996_row2_col0" class="data row2 col0" >25.8</td>
#       <td id="T_bd996_row2_col1" class="data row2 col1" >30.6</td>
#       <td id="T_bd996_row2_col2" class="data row2 col2" >34.2</td>
#       <td id="T_bd996_row2_col3" class="data row2 col3" >37.2</td>
#     </tr>
#     <tr>
#       <th id="T_bd996_level0_row3" class="row_heading level0 row3" >70000</th>
#       <td id="T_bd996_row3_col0" class="data row3 col0" >24.0</td>
#       <td id="T_bd996_row3_col1" class="data row3 col1" >28.7</td>
#       <td id="T_bd996_row3_col2" class="data row3 col2" >32.3</td>
#       <td id="T_bd996_row3_col3" class="data row3 col3" >35.1</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Promos Every N Years vs. Cost of Living Raise</h2>
# <style type="text/css">
# #T_c5038_row0_col0 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_c5038_row0_col1 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_c5038_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c5038_row1_col0 {
#   background-color: #fa9656;
#   color: #000000;
# }
# #T_c5038_row1_col1 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_c5038_row1_col2 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
# }
# #T_c5038_row2_col0 {
#   background-color: #db382b;
#   color: #f1f1f1;
# }
# #T_c5038_row2_col1 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_c5038_row2_col2 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_c5038_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_c5038_row3_col1 {
#   background-color: #fdb96a;
#   color: #000000;
# }
# #T_c5038_row3_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# </style>
# <table id="T_c5038_">
#   <caption>Years to Retirement - Promos Every N Years vs. Cost of Living Raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.01</th>
#       <th class="col_heading level0 col1" >0.02</th>
#       <th class="col_heading level0 col2" >0.03</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Promos Every N Years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5038_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_c5038_row0_col0" class="data row0 col0" >33.6</td>
#       <td id="T_c5038_row0_col1" class="data row0 col1" >31.4</td>
#       <td id="T_c5038_row0_col2" class="data row0 col2" >29.6</td>
#     </tr>
#     <tr>
#       <th id="T_c5038_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_c5038_row1_col0" class="data row1 col0" >35.2</td>
#       <td id="T_c5038_row1_col1" class="data row1 col1" >32.9</td>
#       <td id="T_c5038_row1_col2" class="data row1 col2" >30.9</td>
#     </tr>
#     <tr>
#       <th id="T_c5038_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_c5038_row2_col0" class="data row2 col0" >36.4</td>
#       <td id="T_c5038_row2_col1" class="data row2 col1" >34.0</td>
#       <td id="T_c5038_row2_col2" class="data row2 col2" >31.8</td>
#     </tr>
#     <tr>
#       <th id="T_c5038_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_c5038_row3_col0" class="data row3 col0" >37.2</td>
#       <td id="T_c5038_row3_col1" class="data row3 col1" >34.8</td>
#       <td id="T_c5038_row3_col2" class="data row3 col2" >32.5</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Promos Every N Years vs. Promotion Raise</h2>
# <style type="text/css">
# #T_35f81_row0_col0, #T_35f81_row3_col2 {
#   background-color: #fed683;
#   color: #000000;
# }
# #T_35f81_row0_col1 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_35f81_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_35f81_row1_col0 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_35f81_row1_col1 {
#   background-color: #fffab6;
#   color: #000000;
# }
# #T_35f81_row1_col2 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_35f81_row2_col0 {
#   background-color: #d02927;
#   color: #f1f1f1;
# }
# #T_35f81_row2_col1 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_35f81_row2_col2 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_35f81_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_35f81_row3_col1 {
#   background-color: #f46d43;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_35f81_">
#   <caption>Years to Retirement - Promos Every N Years vs. Promotion Raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.1</th>
#       <th class="col_heading level0 col1" >0.15</th>
#       <th class="col_heading level0 col2" >0.2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Promos Every N Years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35f81_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_35f81_row0_col0" class="data row0 col0" >33.6</td>
#       <td id="T_35f81_row0_col1" class="data row0 col1" >31.4</td>
#       <td id="T_35f81_row0_col2" class="data row0 col2" >29.5</td>
#     </tr>
#     <tr>
#       <th id="T_35f81_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_35f81_row1_col0" class="data row1 col0" >34.7</td>
#       <td id="T_35f81_row1_col1" class="data row1 col1" >32.9</td>
#       <td id="T_35f81_row1_col2" class="data row1 col2" >31.4</td>
#     </tr>
#     <tr>
#       <th id="T_35f81_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_35f81_row2_col0" class="data row2 col0" >35.5</td>
#       <td id="T_35f81_row2_col1" class="data row2 col1" >34.0</td>
#       <td id="T_35f81_row2_col2" class="data row2 col2" >32.6</td>
#     </tr>
#     <tr>
#       <th id="T_35f81_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_35f81_row3_col0" class="data row3 col0" >36.1</td>
#       <td id="T_35f81_row3_col1" class="data row3 col1" >34.8</td>
#       <td id="T_35f81_row3_col2" class="data row3 col2" >33.6</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Promos Every N Years vs. Savings Rate</h2>
# <style type="text/css">
# #T_44a23_row0_col0 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_44a23_row0_col1 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_44a23_row0_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_44a23_row0_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_44a23_row1_col0 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
# }
# #T_44a23_row1_col1 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_44a23_row1_col2 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_44a23_row1_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_44a23_row2_col0 {
#   background-color: #be1827;
#   color: #f1f1f1;
# }
# #T_44a23_row2_col1 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# #T_44a23_row2_col2 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_44a23_row2_col3 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_44a23_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_44a23_row3_col1 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_44a23_row3_col2 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_44a23_row3_col3 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_44a23_">
#   <caption>Years to Retirement - Promos Every N Years vs. Savings Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.1</th>
#       <th class="col_heading level0 col1" >0.2</th>
#       <th class="col_heading level0 col2" >0.3</th>
#       <th class="col_heading level0 col3" >0.4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Promos Every N Years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_44a23_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_44a23_row0_col0" class="data row0 col0" >41.2</td>
#       <td id="T_44a23_row0_col1" class="data row0 col1" >32.5</td>
#       <td id="T_44a23_row0_col2" class="data row0 col2" >27.8</td>
#       <td id="T_44a23_row0_col3" class="data row0 col3" >24.6</td>
#     </tr>
#     <tr>
#       <th id="T_44a23_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_44a23_row1_col0" class="data row1 col0" >43.4</td>
#       <td id="T_44a23_row1_col1" class="data row1 col1" >34.0</td>
#       <td id="T_44a23_row1_col2" class="data row1 col2" >29.0</td>
#       <td id="T_44a23_row1_col3" class="data row1 col3" >25.6</td>
#     </tr>
#     <tr>
#       <th id="T_44a23_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_44a23_row2_col0" class="data row2 col0" >44.9</td>
#       <td id="T_44a23_row2_col1" class="data row2 col1" >35.1</td>
#       <td id="T_44a23_row2_col2" class="data row2 col2" >29.9</td>
#       <td id="T_44a23_row2_col3" class="data row2 col3" >26.3</td>
#     </tr>
#     <tr>
#       <th id="T_44a23_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_44a23_row3_col0" class="data row3 col0" >46.0</td>
#       <td id="T_44a23_row3_col1" class="data row3 col1" >36.0</td>
#       <td id="T_44a23_row3_col2" class="data row3 col2" >30.5</td>
#       <td id="T_44a23_row3_col3" class="data row3 col3" >26.9</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Promos Every N Years vs. Interest Rate</h2>
# <style type="text/css">
# #T_4d77a_row0_col0 {
#   background-color: #fee28f;
#   color: #000000;
# }
# #T_4d77a_row0_col1 {
#   background-color: #dff293;
#   color: #000000;
# }
# #T_4d77a_row0_col2 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_4d77a_row0_col3 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_4d77a_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_4d77a_row1_col0 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_4d77a_row1_col1 {
#   background-color: #feea9b;
#   color: #000000;
# }
# #T_4d77a_row1_col2 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_4d77a_row1_col3 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_4d77a_row1_col4 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_4d77a_row2_col0 {
#   background-color: #d83128;
#   color: #f1f1f1;
# }
# #T_4d77a_row2_col1 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_4d77a_row2_col2 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_4d77a_row2_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_4d77a_row2_col4 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_4d77a_row3_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_4d77a_row3_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_4d77a_row3_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_4d77a_row3_col3 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_4d77a_row3_col4 {
#   background-color: #5db961;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4d77a_">
#   <caption>Years to Retirement - Promos Every N Years vs. Interest Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.03</th>
#       <th class="col_heading level0 col1" >0.04</th>
#       <th class="col_heading level0 col2" >0.05</th>
#       <th class="col_heading level0 col3" >0.06</th>
#       <th class="col_heading level0 col4" >0.07</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Promos Every N Years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d77a_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_4d77a_row0_col0" class="data row0 col0" >35.1</td>
#       <td id="T_4d77a_row0_col1" class="data row0 col1" >33.1</td>
#       <td id="T_4d77a_row0_col2" class="data row0 col2" >31.4</td>
#       <td id="T_4d77a_row0_col3" class="data row0 col3" >29.7</td>
#       <td id="T_4d77a_row0_col4" class="data row0 col4" >28.3</td>
#     </tr>
#     <tr>
#       <th id="T_4d77a_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_4d77a_row1_col0" class="data row1 col0" >37.2</td>
#       <td id="T_4d77a_row1_col1" class="data row1 col1" >34.8</td>
#       <td id="T_4d77a_row1_col2" class="data row1 col2" >32.8</td>
#       <td id="T_4d77a_row1_col3" class="data row1 col3" >30.9</td>
#       <td id="T_4d77a_row1_col4" class="data row1 col4" >29.3</td>
#     </tr>
#     <tr>
#       <th id="T_4d77a_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_4d77a_row2_col0" class="data row2 col0" >38.7</td>
#       <td id="T_4d77a_row2_col1" class="data row2 col1" >36.1</td>
#       <td id="T_4d77a_row2_col2" class="data row2 col2" >33.8</td>
#       <td id="T_4d77a_row2_col3" class="data row2 col3" >31.8</td>
#       <td id="T_4d77a_row2_col4" class="data row2 col4" >29.9</td>
#     </tr>
#     <tr>
#       <th id="T_4d77a_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_4d77a_row3_col0" class="data row3 col0" >39.9</td>
#       <td id="T_4d77a_row3_col1" class="data row3 col1" >37.0</td>
#       <td id="T_4d77a_row3_col2" class="data row3 col2" >34.6</td>
#       <td id="T_4d77a_row3_col3" class="data row3 col3" >32.3</td>
#       <td id="T_4d77a_row3_col4" class="data row3 col4" >30.5</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Promos Every N Years vs. Desired Cash</h2>
# <style type="text/css">
# #T_c552a_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_c552a_row0_col1 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_c552a_row0_col2 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_c552a_row0_col3, #T_c552a_row2_col2 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_c552a_row1_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
# }
# #T_c552a_row1_col1 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_c552a_row1_col2 {
#   background-color: #fdc776;
#   color: #000000;
# }
# #T_c552a_row1_col3 {
#   background-color: #e54e35;
#   color: #f1f1f1;
# }
# #T_c552a_row2_col0 {
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_c552a_row2_col1 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_c552a_row2_col3 {
#   background-color: #c41e27;
#   color: #f1f1f1;
# }
# #T_c552a_row3_col0 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_c552a_row3_col1 {
#   background-color: #fff8b4;
#   color: #000000;
# }
# #T_c552a_row3_col2 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_c552a_row3_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c552a_">
#   <caption>Years to Retirement - Promos Every N Years vs. Desired Cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1000000</th>
#       <th class="col_heading level0 col1" >1500000</th>
#       <th class="col_heading level0 col2" >2000000</th>
#       <th class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Promos Every N Years</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c552a_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_c552a_row0_col0" class="data row0 col0" >25.7</td>
#       <td id="T_c552a_row0_col1" class="data row0 col1" >30.3</td>
#       <td id="T_c552a_row0_col2" class="data row0 col2" >33.7</td>
#       <td id="T_c552a_row0_col3" class="data row0 col3" >36.5</td>
#     </tr>
#     <tr>
#       <th id="T_c552a_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_c552a_row1_col0" class="data row1 col0" >26.8</td>
#       <td id="T_c552a_row1_col1" class="data row1 col1" >31.7</td>
#       <td id="T_c552a_row1_col2" class="data row1 col2" >35.3</td>
#       <td id="T_c552a_row1_col3" class="data row1 col3" >38.3</td>
#     </tr>
#     <tr>
#       <th id="T_c552a_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_c552a_row2_col0" class="data row2 col0" >27.6</td>
#       <td id="T_c552a_row2_col1" class="data row2 col1" >32.6</td>
#       <td id="T_c552a_row2_col2" class="data row2 col2" >36.5</td>
#       <td id="T_c552a_row2_col3" class="data row2 col3" >39.5</td>
#     </tr>
#     <tr>
#       <th id="T_c552a_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_c552a_row3_col0" class="data row3 col0" >28.2</td>
#       <td id="T_c552a_row3_col1" class="data row3 col1" >33.4</td>
#       <td id="T_c552a_row3_col2" class="data row3 col2" >37.3</td>
#       <td id="T_c552a_row3_col3" class="data row3 col3" >40.5</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Cost of Living Raise vs. Promotion Raise</h2>
# <style type="text/css">
# #T_64827_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_64827_row0_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_64827_row0_col2 {
#   background-color: #fff6b0;
#   color: #000000;
# }
# #T_64827_row1_col0 {
#   background-color: #fdbd6d;
#   color: #000000;
# }
# #T_64827_row1_col1 {
#   background-color: #ebf7a3;
#   color: #000000;
# }
# #T_64827_row1_col2 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_64827_row2_col0 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_64827_row2_col1 {
#   background-color: #51b35e;
#   color: #f1f1f1;
# }
# #T_64827_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64827_">
#   <caption>Years to Retirement - Cost of Living Raise vs. Promotion Raise</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.1</th>
#       <th class="col_heading level0 col1" >0.15</th>
#       <th class="col_heading level0 col2" >0.2</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cost of Living Raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64827_level0_row0" class="row_heading level0 row0" >0.01</th>
#       <td id="T_64827_row0_col0" class="data row0 col0" >37.4</td>
#       <td id="T_64827_row0_col1" class="data row0 col1" >35.5</td>
#       <td id="T_64827_row0_col2" class="data row0 col2" >33.8</td>
#     </tr>
#     <tr>
#       <th id="T_64827_level0_row1" class="row_heading level0 row1" >0.02</th>
#       <td id="T_64827_row1_col0" class="data row1 col0" >34.9</td>
#       <td id="T_64827_row1_col1" class="data row1 col1" >33.2</td>
#       <td id="T_64827_row1_col2" class="data row1 col2" >31.7</td>
#     </tr>
#     <tr>
#       <th id="T_64827_level0_row2" class="row_heading level0 row2" >0.03</th>
#       <td id="T_64827_row2_col0" class="data row2 col0" >32.6</td>
#       <td id="T_64827_row2_col1" class="data row2 col1" >31.1</td>
#       <td id="T_64827_row2_col2" class="data row2 col2" >29.8</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Cost of Living Raise vs. Savings Rate</h2>
# <style type="text/css">
# #T_76945_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_76945_row0_col1 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_76945_row0_col2 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_76945_row0_col3, #T_76945_row2_col2 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_76945_row1_col0 {
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_76945_row1_col1 {
#   background-color: #e8f59f;
#   color: #000000;
# }
# #T_76945_row1_col2 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_76945_row1_col3 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_76945_row2_col0 {
#   background-color: #fba05b;
#   color: #000000;
# }
# #T_76945_row2_col1 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_76945_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_76945_">
#   <caption>Years to Retirement - Cost of Living Raise vs. Savings Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.1</th>
#       <th class="col_heading level0 col1" >0.2</th>
#       <th class="col_heading level0 col2" >0.3</th>
#       <th class="col_heading level0 col3" >0.4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cost of Living Raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76945_level0_row0" class="row_heading level0 row0" >0.01</th>
#       <td id="T_76945_row0_col0" class="data row0 col0" >47.1</td>
#       <td id="T_76945_row0_col1" class="data row0 col1" >36.7</td>
#       <td id="T_76945_row0_col2" class="data row0 col2" >31.1</td>
#       <td id="T_76945_row0_col3" class="data row0 col3" >27.4</td>
#     </tr>
#     <tr>
#       <th id="T_76945_level0_row1" class="row_heading level0 row1" >0.02</th>
#       <td id="T_76945_row1_col0" class="data row1 col0" >43.8</td>
#       <td id="T_76945_row1_col1" class="data row1 col1" >34.3</td>
#       <td id="T_76945_row1_col2" class="data row1 col2" >29.2</td>
#       <td id="T_76945_row1_col3" class="data row1 col3" >25.8</td>
#     </tr>
#     <tr>
#       <th id="T_76945_level0_row2" class="row_heading level0 row2" >0.03</th>
#       <td id="T_76945_row2_col0" class="data row2 col0" >40.8</td>
#       <td id="T_76945_row2_col1" class="data row2 col1" >32.2</td>
#       <td id="T_76945_row2_col2" class="data row2 col2" >27.5</td>
#       <td id="T_76945_row2_col3" class="data row2 col3" >24.4</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Cost of Living Raise vs. Interest Rate</h2>
# <style type="text/css">
# #T_47a19_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_47a19_row0_col1 {
#   background-color: #f88950;
#   color: #f1f1f1;
# }
# #T_47a19_row0_col2 {
#   background-color: #feeda1;
#   color: #000000;
# }
# #T_47a19_row0_col3 {
#   background-color: #cbe982;
#   color: #000000;
# }
# #T_47a19_row0_col4 {
#   background-color: #73c264;
#   color: #000000;
# }
# #T_47a19_row1_col0 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_47a19_row1_col1 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_47a19_row1_col2 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_47a19_row1_col3 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_47a19_row1_col4 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_47a19_row2_col0 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_47a19_row2_col1 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_47a19_row2_col2 {
#   background-color: #78c565;
#   color: #000000;
# }
# #T_47a19_row2_col3 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_47a19_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_47a19_">
#   <caption>Years to Retirement - Cost of Living Raise vs. Interest Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.03</th>
#       <th class="col_heading level0 col1" >0.04</th>
#       <th class="col_heading level0 col2" >0.05</th>
#       <th class="col_heading level0 col3" >0.06</th>
#       <th class="col_heading level0 col4" >0.07</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cost of Living Raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47a19_level0_row0" class="row_heading level0 row0" >0.01</th>
#       <td id="T_47a19_row0_col0" class="data row0 col0" >41.0</td>
#       <td id="T_47a19_row0_col1" class="data row0 col1" >37.9</td>
#       <td id="T_47a19_row0_col2" class="data row0 col2" >35.3</td>
#       <td id="T_47a19_row0_col3" class="data row0 col3" >32.9</td>
#       <td id="T_47a19_row0_col4" class="data row0 col4" >30.9</td>
#     </tr>
#     <tr>
#       <th id="T_47a19_level0_row1" class="row_heading level0 row1" >0.02</th>
#       <td id="T_47a19_row1_col0" class="data row1 col0" >37.5</td>
#       <td id="T_47a19_row1_col1" class="data row1 col1" >35.2</td>
#       <td id="T_47a19_row1_col2" class="data row1 col2" >33.1</td>
#       <td id="T_47a19_row1_col3" class="data row1 col3" >31.2</td>
#       <td id="T_47a19_row1_col4" class="data row1 col4" >29.5</td>
#     </tr>
#     <tr>
#       <th id="T_47a19_level0_row2" class="row_heading level0 row2" >0.03</th>
#       <td id="T_47a19_row2_col0" class="data row2 col0" >34.6</td>
#       <td id="T_47a19_row2_col1" class="data row2 col1" >32.7</td>
#       <td id="T_47a19_row2_col2" class="data row2 col2" >31.1</td>
#       <td id="T_47a19_row2_col3" class="data row2 col3" >29.5</td>
#       <td id="T_47a19_row2_col4" class="data row2 col4" >28.1</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Cost of Living Raise vs. Desired Cash</h2>
# <style type="text/css">
# #T_aeac2_row0_col0 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_aeac2_row0_col1 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_aeac2_row0_col2 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_aeac2_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_aeac2_row1_col0 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_aeac2_row1_col1 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_aeac2_row1_col2 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_aeac2_row1_col3 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
# }
# #T_aeac2_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_aeac2_row2_col1 {
#   background-color: #9bd469;
#   color: #000000;
# }
# #T_aeac2_row2_col2 {
#   background-color: #fdfebc;
#   color: #000000;
# }
# #T_aeac2_row2_col3 {
#   background-color: #fdc171;
#   color: #000000;
# }
# </style>
# <table id="T_aeac2_">
#   <caption>Years to Retirement - Cost of Living Raise vs. Desired Cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1000000</th>
#       <th class="col_heading level0 col1" >1500000</th>
#       <th class="col_heading level0 col2" >2000000</th>
#       <th class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Cost of Living Raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aeac2_level0_row0" class="row_heading level0 row0" >0.01</th>
#       <td id="T_aeac2_row0_col0" class="data row0 col0" >28.7</td>
#       <td id="T_aeac2_row0_col1" class="data row0 col1" >34.1</td>
#       <td id="T_aeac2_row0_col2" class="data row0 col2" >38.1</td>
#       <td id="T_aeac2_row0_col3" class="data row0 col3" >41.4</td>
#     </tr>
#     <tr>
#       <th id="T_aeac2_level0_row1" class="row_heading level0 row1" >0.02</th>
#       <td id="T_aeac2_row1_col0" class="data row1 col0" >27.0</td>
#       <td id="T_aeac2_row1_col1" class="data row1 col1" >31.9</td>
#       <td id="T_aeac2_row1_col2" class="data row1 col2" >35.6</td>
#       <td id="T_aeac2_row1_col3" class="data row1 col3" >38.6</td>
#     </tr>
#     <tr>
#       <th id="T_aeac2_level0_row2" class="row_heading level0 row2" >0.03</th>
#       <td id="T_aeac2_row2_col0" class="data row2 col0" >25.4</td>
#       <td id="T_aeac2_row2_col1" class="data row2 col1" >30.0</td>
#       <td id="T_aeac2_row2_col2" class="data row2 col2" >33.3</td>
#       <td id="T_aeac2_row2_col3" class="data row2 col3" >36.0</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Promotion Raise vs. Savings Rate</h2>
# <style type="text/css">
# #T_aa4b5_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_aa4b5_row0_col1 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_aa4b5_row0_col2 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_aa4b5_row0_col3 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_aa4b5_row1_col0 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_aa4b5_row1_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
# }
# #T_aa4b5_row1_col2 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_aa4b5_row1_col3 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_aa4b5_row2_col0 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_aa4b5_row2_col1 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_aa4b5_row2_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_aa4b5_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_aa4b5_">
#   <caption>Years to Retirement - Promotion Raise vs. Savings Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.1</th>
#       <th class="col_heading level0 col1" >0.2</th>
#       <th class="col_heading level0 col2" >0.3</th>
#       <th class="col_heading level0 col3" >0.4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Promotion Raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa4b5_level0_row0" class="row_heading level0 row0" >0.1</th>
#       <td id="T_aa4b5_row0_col0" class="data row0 col0" >46.3</td>
# ...
#   color: #f1f1f1;
# }
# #T_94ff6_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_94ff6_">
#   <caption>Years to Retirement - Promotion Raise vs. Interest Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.03</th>
#       <th class="col_heading level0 col1" >0.04</th>
#       <th class="col_heading level0 col2" >0.05</th>
#       <th class="col_heading level0 col3" >0.06</th>
#       <th class="col_heading level0 col4" >0.07</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Promotion Raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94ff6_level0_row0" class="row_heading level0 row0" >0.1</th>
#       <td id="T_94ff6_row0_col0" class="data row0 col0" >40.1</td>
#       <td id="T_94ff6_row0_col1" class="data row0 col1" >37.2</td>
#       <td id="T_94ff6_row0_col2" class="data row0 col2" >34.7</td>
#       <td id="T_94ff6_row0_col3" class="data row0 col3" >32.4</td>
#       <td id="T_94ff6_row0_col4" class="data row0 col4" >30.5</td>
#     </tr>
#     <tr>
#       <th id="T_94ff6_level0_row1" class="row_heading level0 row1" >0.15</th>
#       <td id="T_94ff6_row1_col0" class="data row1 col0" >37.6</td>
#       <td id="T_94ff6_row1_col1" class="data row1 col1" >35.1</td>
#       <td id="T_94ff6_row1_col2" class="data row1 col2" >33.1</td>
#       <td id="T_94ff6_row1_col3" class="data row1 col3" >31.2</td>
#       <td id="T_94ff6_row1_col4" class="data row1 col4" >29.5</td>
#     </tr>
#     <tr>
#       <th id="T_94ff6_level0_row2" class="row_heading level0 row2" >0.2</th>
#       <td id="T_94ff6_row2_col0" class="data row2 col0" >35.4</td>
#       <td id="T_94ff6_row2_col1" class="data row2 col1" >33.4</td>
#       <td id="T_94ff6_row2_col2" class="data row2 col2" >31.7</td>
#       <td id="T_94ff6_row2_col3" class="data row2 col3" >30.0</td>
#       <td id="T_94ff6_row2_col4" class="data row2 col4" >28.5</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Promotion Raise vs. Desired Cash</h2>
# <style type="text/css">
# #T_71fd0_row0_col0 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_71fd0_row0_col1 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_71fd0_row0_col2 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_71fd0_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_71fd0_row1_col0 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_71fd0_row1_col1 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_71fd0_row1_col2 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_71fd0_row1_col3 {
#   background-color: #e34933;
#   color: #f1f1f1;
# }
# #T_71fd0_row2_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_71fd0_row2_col1 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_71fd0_row2_col2 {
#   background-color: #fff1a8;
#   color: #000000;
# }
# #T_71fd0_row2_col3 {
#   background-color: #fa9857;
#   color: #000000;
# }
# </style>
# <table id="T_71fd0_">
#   <caption>Years to Retirement - Promotion Raise vs. Desired Cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1000000</th>
#       <th class="col_heading level0 col1" >1500000</th>
#       <th class="col_heading level0 col2" >2000000</th>
#       <th class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Promotion Raise</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71fd0_level0_row0" class="row_heading level0 row0" >0.1</th>
#       <td id="T_71fd0_row0_col0" class="data row0 col0" >28.2</td>
#       <td id="T_71fd0_row0_col1" class="data row0 col1" >33.5</td>
#       <td id="T_71fd0_row0_col2" class="data row0 col2" >37.5</td>
#       <td id="T_71fd0_row0_col3" class="data row0 col3" >40.7</td>
#     </tr>
#     <tr>
#       <th id="T_71fd0_level0_row1" class="row_heading level0 row1" >0.15</th>
#       <td id="T_71fd0_row1_col0" class="data row1 col0" >27.0</td>
#       <td id="T_71fd0_row1_col1" class="data row1 col1" >31.9</td>
#       <td id="T_71fd0_row1_col2" class="data row1 col2" >35.6</td>
#       <td id="T_71fd0_row1_col3" class="data row1 col3" >38.6</td>
#     </tr>
#     <tr>
#       <th id="T_71fd0_level0_row2" class="row_heading level0 row2" >0.2</th>
#       <td id="T_71fd0_row2_col0" class="data row2 col0" >25.9</td>
#       <td id="T_71fd0_row2_col1" class="data row2 col1" >30.5</td>
#       <td id="T_71fd0_row2_col2" class="data row2 col2" >34.0</td>
#       <td id="T_71fd0_row2_col3" class="data row2 col3" >36.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Savings Rate vs. Interest Rate</h2>
# <style type="text/css">
# #T_12fa0_row0_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_12fa0_row0_col1 {
#   background-color: #e0422f;
#   color: #f1f1f1;
# }
# #T_12fa0_row0_col2 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_12fa0_row0_col3 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_12fa0_row0_col4 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_12fa0_row1_col0 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_12fa0_row1_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_12fa0_row1_col2 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_12fa0_row1_col3 {
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_12fa0_row1_col4 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_12fa0_row2_col0 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_12fa0_row2_col1 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_12fa0_row2_col2 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_12fa0_row2_col3 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_12fa0_row2_col4 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_12fa0_row3_col0 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_12fa0_row3_col1 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_12fa0_row3_col2 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_12fa0_row3_col3 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_12fa0_row3_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_12fa0_">
#   <caption>Years to Retirement - Savings Rate vs. Interest Rate</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0.03</th>
#       <th class="col_heading level0 col1" >0.04</th>
#       <th class="col_heading level0 col2" >0.05</th>
#       <th class="col_heading level0 col3" >0.06</th>
#       <th class="col_heading level0 col4" >0.07</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Savings Rate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12fa0_level0_row0" class="row_heading level0 row0" >0.1</th>
#       <td id="T_12fa0_row0_col0" class="data row0 col0" >50.2</td>
#       <td id="T_12fa0_row0_col1" class="data row0 col1" >46.7</td>
#       <td id="T_12fa0_row0_col2" class="data row0 col2" >43.5</td>
#       <td id="T_12fa0_row0_col3" class="data row0 col3" >40.7</td>
#       <td id="T_12fa0_row0_col4" class="data row0 col4" >38.2</td>
#     </tr>
#     <tr>
#       <th id="T_12fa0_level0_row1" class="row_heading level0 row1" >0.2</th>
#       <td id="T_12fa0_row1_col0" class="data row1 col0" >38.9</td>
#       <td id="T_12fa0_row1_col1" class="data row1 col1" >36.3</td>
#       <td id="T_12fa0_row1_col2" class="data row1 col2" >34.2</td>
#       <td id="T_12fa0_row1_col3" class="data row1 col3" >32.2</td>
#       <td id="T_12fa0_row1_col4" class="data row1 col4" >30.4</td>
#     </tr>
#     <tr>
#       <th id="T_12fa0_level0_row2" class="row_heading level0 row2" >0.3</th>
#       <td id="T_12fa0_row2_col0" class="data row2 col0" >32.8</td>
#       <td id="T_12fa0_row2_col1" class="data row2 col1" >30.8</td>
#       <td id="T_12fa0_row2_col2" class="data row2 col2" >29.1</td>
#       <td id="T_12fa0_row2_col3" class="data row2 col3" >27.5</td>
#       <td id="T_12fa0_row2_col4" class="data row2 col4" >26.1</td>
#     </tr>
#     <tr>
#       <th id="T_12fa0_level0_row3" class="row_heading level0 row3" >0.4</th>
#       <td id="T_12fa0_row3_col0" class="data row3 col0" >28.8</td>
#       <td id="T_12fa0_row3_col1" class="data row3 col1" >27.2</td>
#       <td id="T_12fa0_row3_col2" class="data row3 col2" >25.7</td>
#       <td id="T_12fa0_row3_col3" class="data row3 col3" >24.4</td>
#       <td id="T_12fa0_row3_col4" class="data row3 col4" >23.2</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Savings Rate vs. Desired Cash</h2>
# <style type="text/css">
# #T_38640_row0_col0, #T_38640_row1_col2 {
#   background-color: #feec9f;
#   color: #000000;
# }
# #T_38640_row0_col1 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_38640_row0_col2 {
#   background-color: #da362a;
#   color: #f1f1f1;
# }
# #T_38640_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_38640_row1_col0, #T_38640_row2_col1, #T_38640_row3_col2 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_38640_row1_col1 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_38640_row1_col3 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_38640_row2_col0 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_38640_row2_col2 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_38640_row2_col3 {
#   background-color: #f7fcb4;
#   color: #000000;
# }
# #T_38640_row3_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_38640_row3_col1 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_38640_row3_col3 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# </style>
# <table id="T_38640_">
#   <caption>Years to Retirement - Savings Rate vs. Desired Cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1000000</th>
#       <th class="col_heading level0 col1" >1500000</th>
#       <th class="col_heading level0 col2" >2000000</th>
#       <th class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Savings Rate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38640_level0_row0" class="row_heading level0 row0" >0.1</th>
#       <td id="T_38640_row0_col0" class="data row0 col0" >36.8</td>
#       <td id="T_38640_row0_col1" class="data row0 col1" >42.4</td>
#       <td id="T_38640_row0_col2" class="data row0 col2" >46.5</td>
#       <td id="T_38640_row0_col3" class="data row0 col3" >49.8</td>
#     </tr>
#     <tr>
#       <th id="T_38640_level0_row1" class="row_heading level0 row1" >0.2</th>
#       <td id="T_38640_row1_col0" class="data row1 col0" >28.0</td>
#       <td id="T_38640_row1_col1" class="data row1 col1" >33.0</td>
#       <td id="T_38640_row1_col2" class="data row1 col2" >36.8</td>
#       <td id="T_38640_row1_col3" class="data row1 col3" >39.8</td>
#     </tr>
#     <tr>
#       <th id="T_38640_level0_row2" class="row_heading level0 row2" >0.3</th>
#       <td id="T_38640_row2_col0" class="data row2 col0" >23.3</td>
#       <td id="T_38640_row2_col1" class="data row2 col1" >28.0</td>
#       <td id="T_38640_row2_col2" class="data row2 col2" >31.5</td>
#       <td id="T_38640_row2_col3" class="data row2 col3" >34.4</td>
#     </tr>
#     <tr>
#       <th id="T_38640_level0_row3" class="row_heading level0 row3" >0.4</th>
#       <td id="T_38640_row3_col0" class="data row3 col0" >20.2</td>
#       <td id="T_38640_row3_col1" class="data row3 col1" >24.6</td>
#       <td id="T_38640_row3_col2" class="data row3 col2" >28.0</td>
#       <td id="T_38640_row3_col3" class="data row3 col3" >30.7</td>
#     </tr>
#   </tbody>
# </table>
# <h2>Years to Retirement by Interest Rate vs. Desired Cash</h2>
# <style type="text/css">
# #T_fc43e_row0_col0 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_fc43e_row0_col1, #T_fc43e_row3_col3 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_fc43e_row0_col2 {
#   background-color: #ee613e;
#   color: #f1f1f1;
# }
# #T_fc43e_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_fc43e_row1_col0 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_fc43e_row1_col1 {
#   background-color: #f8fcb6;
#   color: #000000;
# }
# #T_fc43e_row1_col2 {
#   background-color: #fdb567;
#   color: #000000;
# }
# #T_fc43e_row1_col3 {
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_fc43e_row2_col0 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_fc43e_row2_col1 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_fc43e_row2_col2 {
#   background-color: #feeb9d;
#   color: #000000;
# }
# #T_fc43e_row2_col3 {
#   background-color: #fba35c;
#   color: #000000;
# }
# #T_fc43e_row3_col0 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_fc43e_row3_col1 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_fc43e_row3_col2 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_fc43e_row4_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_fc43e_row4_col1 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_fc43e_row4_col2 {
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_fc43e_row4_col3 {
#   background-color: #fbfdba;
#   color: #000000;
# }
# </style>
# <table id="T_fc43e_">
#   <caption>Years to Retirement - Interest Rate vs. Desired Cash</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >1000000</th>
#       <th class="col_heading level0 col1" >1500000</th>
#       <th class="col_heading level0 col2" >2000000</th>
#       <th class="col_heading level0 col3" >2500000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Interest Rate</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc43e_level0_row0" class="row_heading level0 row0" >0.03</th>
#       <td id="T_fc43e_row0_col0" class="data row0 col0" >30.2</td>
#       <td id="T_fc43e_row0_col1" class="data row0 col1" >36.1</td>
#       <td id="T_fc43e_row0_col2" class="data row0 col2" >40.5</td>
#       <td id="T_fc43e_row0_col3" class="data row0 col3" >44.0</td>
#     </tr>
#     <tr>
#       <th id="T_fc43e_level0_row1" class="row_heading level0 row1" >0.04</th>
#       <td id="T_fc43e_row1_col0" class="data row1 col0" >28.4</td>
#       <td id="T_fc43e_row1_col1" class="data row1 col1" >33.8</td>
#       <td id="T_fc43e_row1_col2" class="data row1 col2" >37.8</td>
#       <td id="T_fc43e_row1_col3" class="data row1 col3" >41.0</td>
#     </tr>
#     <tr>
#       <th id="T_fc43e_level0_row2" class="row_heading level0 row2" >0.05</th>
#       <td id="T_fc43e_row2_col0" class="data row2 col0" >26.9</td>
#       <td id="T_fc43e_row2_col1" class="data row2 col1" >31.8</td>
#       <td id="T_fc43e_row2_col2" class="data row2 col2" >35.4</td>
#       <td id="T_fc43e_row2_col3" class="data row2 col3" >38.4</td>
#     </tr>
#     <tr>
#       <th id="T_fc43e_level0_row3" class="row_heading level0 row3" >0.06</th>
#       <td id="T_fc43e_row3_col0" class="data row3 col0" >25.5</td>
#       <td id="T_fc43e_row3_col1" class="data row3 col1" >30.0</td>
#       <td id="T_fc43e_row3_col2" class="data row3 col2" >33.3</td>
#       <td id="T_fc43e_row3_col3" class="data row3 col3" >36.0</td>
#     </tr>
#     <tr>
#       <th id="T_fc43e_level0_row4" class="row_heading level0 row4" >0.07</th>
#       <td id="T_fc43e_row4_col0" class="data row4 col0" >24.2</td>
#       <td id="T_fc43e_row4_col1" class="data row4 col1" >28.4</td>
#       <td id="T_fc43e_row4_col2" class="data row4 col2" >31.4</td>
#       <td id="T_fc43e_row4_col3" class="data row4 col3" >33.9</td>
#     </tr>
#   </tbody>
# </table>
